# %%
# Temel kütüphaneler
import pandas as pd
import numpy as np

# Görselleştirme
import matplotlib.pyplot as plt
import seaborn as sns

# Ayarlar
plt.style.use("seaborn-v0_8")
sns.set_palette("Set2")

print("EDA ortamı hazır")
# Out:
# EDA ortamı hazır

# %%
# Veri setini yükleme
df = pd.read_csv("../data/heart.csv")

# İlk 5 satır
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Veri boyutu
df.shape
# Out:
# (1025, 14)

# %%
# Veri seti genel bilgisi
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# Temel istatistikler
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# Target sınıf dağılımı
df['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
sns.countplot(x='target', data=df)
plt.title("Target Sınıf Dağılımı")
plt.show()

# %%
# Duplicate (mükerrer) kayıt sayısı
dup_count = df.duplicated().sum()
dup_count
# Out:
# np.int64(723)

# %%
# Duplicate satırları görmek (varsa)
df[df.duplicated(keep=False)].sort_values(list(df.columns)).head(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 60    29    1   1       130   204    0        0      202      0      0.0
# 64    29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 668   29    1   1       130   204    0        0      202      0      0.0
# 12    34    0   1       118   210    0        1      192      0      0.7
# 15    34    0   1       118   210    0        1      192      0      0.7
# 779   34    0   1       118   210    0        1      192      0      0.7
# 143   34    1   3       118   182    0        0      174      0      0.0
# 201   34    1   3       118   182    0        0      174      0      0.0
# 572   34    1   3       118   182    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 60       2   0     2       1
# 64       2   0     2       1
# 118      2   0     2       1
# 668      2   0     2       1
# ...

# %%
cols = ["chol", "trestbps", "oldpeak"]

plt.figure(figsize=(14, 4))
for i, col in enumerate(cols, 1):
    plt.subplot(1, 3, i)
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot: {col}")
plt.tight_layout()
plt.show()

# %%
def iqr_outliers(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    low = q1 - 1.5 * iqr
    high = q3 + 1.5 * iqr
    return low, high

for col in ["chol", "trestbps", "oldpeak"]:
    low, high = iqr_outliers(df[col])
    out_count = ((df[col] < low) | (df[col] > high)).sum()
    print(f"{col}: low={low:.2f}, high={high:.2f}, outlier_count={out_count}")
# Out:
# chol: low=115.00, high=371.00, outlier_count=16
# trestbps: low=90.00, high=170.00, outlier_count=30
# oldpeak: low=-2.70, high=4.50, outlier_count=7

# %%
plt.figure(figsize=(12, 10))

corr = df.corr()

sns.heatmap(
    corr,
    cmap="coolwarm",
    annot=False,
    linewidths=0.5
)

plt.title("Özellikler Arası Korelasyon Isı Haritası")
plt.show()
